# %%
import pandas as pd
data= pd.read_csv(r"C:\Users\banva\Desktop\stores_data_centroid.csv")

# %%
# To write a Python 2/3 compatible codebase, the first step is to add this line to the top of each module
from __future__ import division, print_function, unicode_literals
# Numpy is the fundamental package for scientific computing with Python. 
# SciPy (pronounced "Sigh Pie") is an open source Python library used for scientific computing and technical computing. 
# Os module provides a portable way of using operating system dependent functionality.
import numpy as np # np is an alias pointing to numpy
import scipy as sp # sp is an alias pointing to scipy
import os 

# Seed the generator to make this notebook's output stable across runs
np.random.seed(42)

# To plot pretty figures
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt #pyplot is matplotlib's plotting framework https://matplotlib.org/users/pyplot_tutorial.html
# Dynamically change the default rc settings in a python script
# See documentation for a complete list of parameters https://matplotlib.org/users/customizing.html
plt.rcParams['axes.labelsize'] = 14  # fontsize of the x any y labels
plt.rcParams['xtick.labelsize'] = 12 # fontsize of the tick labels
plt.rcParams['ytick.labelsize'] = 12 # fontsize of the tick labels

# Where to save the figures
PROJECT_ROOT_DIR = "."
CHAPTER_ID = "decision_trees"

# Define path of an image
# Function that takes as input fig_id and returns back the image path
def image_path(fig_id):
    return os.path.join(PROJECT_ROOT_DIR, "images", CHAPTER_ID, fig_id)
 


# Save image in a specific path
# Function that takes as input fig_id and saves the image in a specific format (i.e., png, 300 dpi)
def save_fig(fig_id, tight_layout=True):
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(image_path(fig_id) + ".png", format='png', dpi=300)

# %%
data.centroids = data["centroids"].astype(str)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 421 entries, 0 to 420
# Data columns (total 16 columns):
# Unnamed: 0       421 non-null int64
# store_id         421 non-null int64
# volume           421 non-null float64
# revenue          421 non-null float64
# profit           421 non-null float64
# transaction      421 non-null int64
# profit_trans     421 non-null float64
# revenue_trans    421 non-null float64
# customer         421 non-null int64
# profit_cust      421 non-null float64
# revenue_cust     421 non-null float64
# discount_rate    421 non-null float64
# discount_freq    421 non-null float64
# weekend_freq     421 non-null float64
# product_types    421 non-null int64
# centroids        421 non-null int64
# dtypes: float64(10), int64(6)
# memory usage: 52.7 KB

# %%
col_list= ['volume', "revenue" , "profit" ,"transaction","customer","discount_rate","discount_freq","weekend_freq","product_types"]

# %%
col_list
# Out:
# ['volume',
#  'revenue',
#  'profit',
#  'transaction',
#  'customer',
#  'discount_rate',
#  'discount_freq',
#  'weekend_freq',
#  'product_types']

# %%
X= data.loc[: ,['volume',"revenue" , "profit" ,"transaction","customer","discount_rate","discount_freq","weekend_freq","product_types"]]

# %%
X.head()
# Out:
#        volume    revenue     profit  transaction  customer  discount_rate  \
# 0  211372.290  321967.06  273971.68        13294       161       0.149069
# 1  559421.824  855125.38  680640.41        25641       416       0.204046
# 2   89029.316  120532.49   99080.57         5532        46       0.177976
# 3  273819.096  433290.81  353938.08        13726       202       0.183140
# 4  116599.042  156213.82  130859.20         6595        64       0.162307
#
#    discount_freq  weekend_freq  product_types
# 0       0.289402      0.277391           7860
# 1       0.382802      0.336914           9273
# 2       0.322633      0.259647           5044
# 3       0.361383      0.379024           8444
# 4       0.305937      0.246409           6283

# %%
y= pd.get_dummies(data['centroids'],drop_first=False)
y.head()
# Out:
#    0  1  2
# 0  0  1  0
# 1  0  1  0
# 2  1  0  0
# 3  0  0  1
# 4  0  1  0

# %%
#cluster_1
y_1 = y.iloc[:, 0]

# %%
#cluster_2
y_2 = y.iloc[:,1]

# %%
#cluster_3
y_3 = y.iloc[:,2]

# %% [markdown]
# Decision Tree for cluster_1

# %%
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_graphviz
import graphviz 

# Training the model with Gini criteria
gini_clf = tree.DecisionTreeClassifier(max_depth=3)
gini_clf = gini_clf.fit(X, y_1)

#get the decision tree graph

feature_names = list(X.columns)   # we need column names in the list form
gini_tree = tree.export_graphviz(gini_clf, out_file=None,
                                feature_names=feature_names,
                                class_names= '01',
                                filled=True, rounded=True,  
                                special_characters=True)

gini_graph = graphviz.Source(gini_tree) 

gini_graph

# %% [markdown]
# Decision tree for cluster_2

# %%
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_graphviz
import graphviz 

# Training the model with Gini criteria
gini_clf = tree.DecisionTreeClassifier(max_depth=3)
gini_clf = gini_clf.fit(X, y_2)

#get the decision tree graph

feature_names = list(X.columns)   # we need column names in the list form
gini_tree = tree.export_graphviz(gini_clf, out_file=None,
                                feature_names=feature_names,
                                class_names= '01',
                                filled=True, rounded=True,  
                                special_characters=True)

gini_graph = graphviz.Source(gini_tree) 

gini_graph

# %% [markdown]
# Decision tree for cluster_2

# %%
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_graphviz
import graphviz 

# Training the model with Gini criteria
gini_clf = tree.DecisionTreeClassifier(max_depth=3)
gini_clf = gini_clf.fit(X, y_2)

#get the decision tree graph

feature_names = list(X.columns)   # we need column names in the list form
gini_tree = tree.export_graphviz(gini_clf, out_file=None,
                                feature_names=feature_names,
                                class_names= '01',
                                filled=True, rounded=True,  
                                special_characters=True)

gini_graph = graphviz.Source(gini_tree) 

gini_graph
